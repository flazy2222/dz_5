# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
df = pd.read_csv('dst-3.0_16_1_hh_database.csv', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
df.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь
def extract_education_level(education_string):
    first_two_words = education_string.split()[:2]
    # Определяем уровень образования по первым двум словам
    if 'Высшее' in first_two_words:
        return 'Высшее'
    elif 'Неоконченное' and 'высшее' in first_two_words:
        return 'Неоконченное высшее'
    elif 'Среднее' and 'специальное' in first_two_words:
        return 'Среднее специальное'
    else : return 'Среднее'

# Применяем функцию
df['Образование'] = df['Образование и ВУЗ'].apply(extract_education_level)


# Удаляем старый признак
df.drop(columns=['Образование и ВУЗ'], inplace=True)

# %%
df.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
# Преобразование пола
def extract_gender(gender_age_string):
    gender = gender_age_string.split(',')[0].strip()
    if 'Мужчина' in gender:
        return 'М'
    else:
        return 'Ж'
    
# Преобразование возраста
def extract_age(gender_age_string):
    age_part = gender_age_string.split(',')[1].strip()
    age = int(age_part.split()[0])
    return age

# Применяем функции

df['Пол'] = df['Пол, возраст'].apply(extract_gender)
df['Возраст'] = df['Пол, возраст'].apply(extract_age) 

# Проверяем уникальные значения
print("Уникальные значения в столбце 'Пол':", df["Пол"].unique())
print("Тип данных столбца 'Возраст':", df["Возраст"].dtype)
print(df['Пол'].value_counts(normalize=True))
print(df.describe())

df.head()

df.drop(columns=['Пол, возраст'], inplace=True)
# Out:
# Уникальные значения в столбце 'Пол': ['М' 'Ж']
# Тип данных столбца 'Возраст': int64
# Пол
# М    0.809293
# Ж    0.190707
# Name: proportion, dtype: float64
#             Возраст
# count  44744.000000
# mean      32.196741
# std        7.929800
# min       14.000000
# 25%       27.000000
# 50%       31.000000
# 75%       36.000000
# max      100.000000

# %%
df.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# ...

# %%
df['Опыт работы'].iloc[3280]
# Out:
# 'Опыт работы 2 месяца  Full-Stack JavaScript Developer 35 000 руб. Информационные технологии, интернет, телеком Программирование, Разработка Продажи Стартапы Занятость: полная занятость График работы: полный день Опыт работы 2 месяца Февраль 2019 — Март  2019 2 месяца [f]-PR Intern Копирайтинг, написание деловых писем, редактирование фотографий Ключевые навыки Теперь резюме открыто всему интернету — изменить можно в настройках видимости. Обучение и развитие JavaScript Node.js CSS3 HTML CSS HTML5 Adobe Photoshop Adobe Illustrator SEO Пользователь ПК Ориентация на результат Английский язык Проведение презентаций Git Prezi Возникли неполадки. Попробуйте еще раз. Обо мне Увлеченно хожу по хакатонам с марта 2019 года, там обычно главный разработчик и пичер. Стек технологий с которым мне было бы интересно работать: node js и всё что с ним связано, react, vue, hyperledger fabric Писал и запускал свой сервер на express js, затем соединял с фронтом от react и посыпал всё это WebSockets Считаю
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь

# Функция для преобразования строки "Опыт работы"
def parse_experience(experience):
    if pd.isna(experience) or experience == "Не указано":
        return np.nan
    experience = experience.split(',')[0]
    # Извлечение числа лет и месяцев с помощью регулярного выражения
    import re
    years = re.search(r'(\d+)\s*(год|года|лет)', experience)
    months = re.search(r'(\d+)\s*(месяц|месяца|месяцев)', experience)

    total_months = 0
    if months:
        total_months += int(months.group(1))
    if years:
        total_months += int(years.group(1)) * 12


    return total_months

# Применяем функцию ко всему столбцу

df["Опыт работы (месяц)"] = df['Опыт работы'].apply(parse_experience)
print(df["Опыт работы (месяц)"])

# Удаляем исходный столбец "Опыт работы"
df.drop(columns=['Опыт работы'], inplace=True)
# Out:
# 0        202.0
# 1        233.0
# 2        123.0
# 3        225.0
# 4         67.0
#          ...
# 44739     91.0
# 44740     84.0
# 44741    257.0
# 44742     46.0
# 44743    190.0
# Name: Опыт работы (месяц), Length: 44744, dtype: float64

# %%
df['Опыт работы (месяц)'].nlargest(50)
# Out:
# 40015    1188.0
# 3293      663.0
# 10044     653.0
# 44363     622.0
# 25135     586.0
# 37144     579.0
# 19628     569.0
# 10773     567.0
# 11444     562.0
# 21963     556.0
# 16657     552.0
# 24735     549.0
# 5780      546.0
# 25884     546.0
# 34226     545.0
# 44414     545.0
# 15419     543.0
# 8390      537.0
# 20821     530.0
# 21824     526.0
# 39626     520.0
# 31902     518.0
# 3460      517.0
# 11        510.0
# 4979      509.0
# 5881      509.0
# 27536     508.0
# 41239     508.0
# 152       507.0
# 13589     507.0
# 23271     506.0
# 14546     502.0
# 26665     500.0
# 40621     499.0
# 9560      498.0
# 1064      497.0
# 10075     497.0
# 43653     497.0
# 5597      496.0
# 1582      495.0
# 32994     494.0
# 17150     493.0
# 12162     490.0
# 19567     490.0
# 31742     490.0
# 39244     490.0
# 22031     489.0
# 20206     488.0
# 39821     487.0
# 23295     485.0
# Name: Опыт работы (месяц), dtype: float64

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь
import re
def parse_city_and_mobility(value):
    if pd.isna(value):
        return pd.Series(["другие", False, False], index=["Город", "Готовность к переезду", "Готовность к командировкам"])

    million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара',
                      'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']
    
    # Разделение строки на части
    parts= value.split(',')
    
    # Извлечение города
    city = parts[0].strip()
    if city not in ['Москва', 'Санкт-Петербург'] + million_cities:
        city = 'Другие'
        
    # Готовность к переезду 
   
    mobility_ready = False
    if re.search(r'не\s*готов[а]? к переезду', value, re.IGNORECASE):
         mobility_ready = False
    elif re.search(r'готов[а]? к переезду|хочу переехать', value, re.IGNORECASE):
        mobility_ready = True

    # Проверка готовности к командировкам
    trips_ready = False

    if re.search(r'не\s*готов[а]? к командировкам', value, re.IGNORECASE):
        trips_ready = False
    elif re.search(r'готов[а]? к командировкам|готов[а]? к редким командировкам', value, re.IGNORECASE):
        trips_ready = True    
    return pd.Series([city, mobility_ready, trips_ready], index=['Город','Готовность к переезду','Готовность к командировкам'])


# Применяем функцию ко всему столбцу
city_column = "Город, переезд, командировки"  # Исправленное имя столбца
df[["Город", "Готовность к переезду", "Готовность к командировкам"]] = df[city_column].apply(parse_city_and_mobility)

# По умолчанию считаем пропуски по командировкам как "не готов к командировкам"
df["Готовность к командировкам"] = df["Готовность к командировкам"].fillna(False)

print(df[["Город", "Готовность к переезду", "Готовность к командировкам"]])
df[["Готовность к переезду", "Готовность к командировкам"]].value_counts(normalize=True )

df.drop(columns=["Город, переезд, командировки"], inplace=True)
# Out:
#            Город  Готовность к переезду  Готовность к командировкам
# 0         Другие                  False                       False
# 1         Другие                  False                        True
# 2         Другие                  False                       False
# 3         Другие                  False                        True
# 4         Москва                  False                        True
# ...          ...                    ...                         ...
# 44739     Другие                   True                        True
# 44740     Другие                   True                        True
# 44741  Челябинск                   True                        True
# 44742     Другие                  False                       False
# 44743     Москва                  False                       False
#
# [44744 rows x 3 columns]

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь
employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

# ohe для 'Занятость'
for category in employment_categories:
    df[category] = df['Занятость'].apply(lambda x: category in str(x))

# ohe для "График"
for category in schedule_categories:
    df[category] = df['График'].apply(lambda x: category in str(x))

df[['проектная работа', 'волонтерство']].value_counts()
df[['вахтовый метод', 'гибкий график']].value_counts()
df.drop(columns=['Занятость', 'График'], inplace=True)

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
df_exchange = pd.read_csv('ExchangeRates.csv')
df_exchange.head()
# Out:
#   currency per      date   time    close  vol  proportion
# 0      USD   D  29/12/17  00:00  57.6291    0           1
# 1      USD   D  30/12/17  00:00  57.6002    0           1
# 2      USD   D  31/12/17  00:00  57.6002    0           1
# 3      USD   D  01/01/18  00:00  57.6002    0           1
# 4      USD   D  02/01/18  00:00  57.6002    0           1

# %%
#ваш код здесь
df['Обновление резюме'] = pd.to_datetime(df['Обновление резюме']).dt.date
df_exchange['date'] = pd.to_datetime(df_exchange['date']).dt.date
df_exchange['date']
# Выделение суммы и валюты из столбца 'ЗП'
def parse_salary(salary):
    if pd.isna(salary):
        return pd.Series([np.nan, np.nan], index= ['ЗП сумма', 'ЗП валюта'])
    parts = salary.split()
    amount, currency = parts
    try:
        amount = float(amount.replace(',', '.'))
    except ValueError:
        amount = np.nan
    return [amount, currency]
df[['ЗП (сумма)', 'ЗП (валюта)']] = pd.DataFrame(df['ЗП'].apply(parse_salary).tolist(),columns=['ЗП (сумма)', 'ЗП (валюта)'])
df[['ЗП (сумма)', 'ЗП (валюта)']]

currency_mapping = {
    'руб.': 'RUB',
    'USD': 'USD',
    'EUR': 'EUR',
    'KZT': 'KZT',
    'грн.': 'UAH',
    'бел.руб.': 'BYN',
    'UZS': 'UZS'
}

df['ЗП (валюта)'] = df['ЗП (валюта)'].map(currency_mapping)

df_exchange.loc[df_exchange['currency'] == 'RUB', 'close'] = 1
df_merged = pd.merge(
    df,
    df_exchange,
    how='left',
    left_on=['Обновление резюме', 'ЗП (валюта)'],
    right_on=['date', 'currency']
    
)
df_merged['close'] = df_merged['close'].fillna(1)  # Курс по умолчанию (например, RUB = 1)
df_merged['proportion'] = df_merged['proportion'].fillna(1)   # Пропорция по умолчанию
# Расчет заработной платы в рублях
df_merged['ЗП (руб)'] = (
    df_merged['ЗП (сумма)'] * df_merged['close'] / df_merged['proportion']
)

df_merged['ЗП (руб)'].nlargest(24)
# Out:
# 6931    24304876.00
# 14051    8500000.00
# 27435    8000000.00
# 39191    7675224.00
# 41489    6000000.00
# 41774    6000000.00
# 41634    5000000.00
# 1394     4000000.00
# 10735    4000000.00
# 26509    4000000.00
# 32273    4000000.00
# 42601    4000000.00
# 19229    3000000.00
# 28253    3000000.00
# 28795    2500000.00
# 41217    2500000.00
# 43134    2500000.00
# 1842     2000000.00
# 34062    2000000.00
# 41924    1750000.00
# 10553    1500000.00
# 12200    1500000.00
# 489      1000000.00
# 31649    1000000.00
# Name: ЗП (руб), dtype: float64

# %%
missing_rates = df_merged[df_merged['close'].isna() | df_merged['proportion'].isna()]
print(missing_rates[['ЗП (валюта)', 'close', 'proportion']])
# Out:
# Empty DataFrame
# Columns: [ЗП (валюта), close, proportion]
# Index: []

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
# Построение распределения признака "Возраст"
plt.figure(figsize=(14, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(df_merged['Возраст'], kde=True, bins=30, color='blue', alpha=0.7)
plt.title('Распределение возраста (гистограмма)')
plt.xlabel('Возраст')
plt.ylabel('Частота')

# Коробчатая диаграмма
plt.subplot(1, 2, 2)
sns.boxplot(x=df_merged['Возраст'], color='blue', width=0.6)
plt.title('Распределение возраста (коробчатая диаграмма)')
plt.xlabel('Возраст')

plt.tight_layout()
plt.show()

# %%
# Основные статистики
mode_age = df_merged['Возраст'].mode()[0]
min_age = df_merged['Возраст'].min()
max_age = df_merged['Возраст'].max()
iqr = df_merged['Возраст'].quantile(0.75) - df_merged['Возраст'].quantile(0.25)
lower_bound = df_merged['Возраст'].quantile(0.25) - 1.5 * iqr
upper_bound = df_merged['Возраст'].quantile(0.75) + 1.5 * iqr

mode_age, min_age, max_age, lower_bound, upper_bound
# Out:
# (30, 14, 100, 13.5, 49.5)

# %% [markdown]
# ваши выводы по графику здесь:
# 1) Мода распределения равна 30.
# 2) Минимальное и максимальное значение - 14 и 100 соответственно
# 3) Большниство возрастов лежит в интервале от 14 до 50.
# 4) Аномальными значениями можно посчитать возраст 13.5 и 100

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
plt.figure(figsize=(14, 6))

# Гистограмма
plt.subplot(1, 2, 1)
sns.histplot(df_merged['Опыт работы (месяц)'], kde= True, color = 'purple')
plt.title('Распределение опыта работы')
plt.xlabel('Опыт работы(месяц)')
plt.ylabel('Частота')
plt.xlim(0, 1200)
plt.subplot(1, 2, 2)
sns.boxplot(x=df_merged['Опыт работы (месяц)'], color='purple', width=0.6)
plt.title('Распределение опыта работы (коробчатая диаграмма)')
plt.xlabel('Опыт работы(месяц)')

plt.tight_layout()
plt.show()

# %%
mode_age = df_merged['Опыт работы (месяц)'].mode()[0]
min_age = df_merged['Опыт работы (месяц)'].min()
max_age = df_merged['Опыт работы (месяц)'].max()
iqr = df_merged['Опыт работы (месяц)'].quantile(0.75) - df_merged['Опыт работы (месяц)'].quantile(0.25)
upper_bound = df_merged['Опыт работы (месяц)'].quantile(0.75) + 1.5 * iqr
mode_age, min_age, max_age, lower_bound, upper_bound
# Out:
# (81.0, 1.0, 1188.0, 13.5, 299.5)

# %% [markdown]
# ваши выводы здесь
# 1) Мода распределения равна 81 месяц
# 2) Минимальное и максимальное значение - 1 и 1188 соответсвенно
# 3) Значения большинства опыта работы находятся в интервале от 0 до 300
# 4) Аномальным значением может быть 1188 месяцев

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
sns.histplot(
    df_merged['ЗП (руб)'], 
    kde=True, 
    bins=1000, 
    color="skyblue", 
    edgecolor="black"
)
mean = df_merged['ЗП (руб)'].mean()
plt.axvline(
    mean, 
    color='red', 
    linestyle='--', 
    label=f'Среднее: {mean:.2f}'
)
median = df_merged['ЗП (руб)'].median()
plt.axvline(
    median, 
    color='green', 
    linestyle='-', 
    label=f'Медиана: {median:.2f}'
)
plt.title('Гистограмма для признака ЗП')
plt.xlabel('Значения')
plt.ylabel('Частота и плотность')
plt.xlim(0, 500000)
plt.legend()

plt.figure(figsize=(16, 3))
sns.boxplot(data=df_merged, x='ЗП (руб)', color='skyblue')
plt.title('Boxplot для признака ЗП')
plt.xlabel('ЗП')

plt.show()

print('Мода:', df_merged['ЗП (руб)'].mode()[0])

print(
    '\nЗначений менее 5к руб:\n', 
    df_merged[df_merged['ЗП (руб)'] < 5000]['ЗП (руб)'].value_counts()
)
print(
    '\nЖелающих ЗП более 1млн руб:', 
    df_merged[df_merged['ЗП (руб)'] > 1000000]['ЗП (руб)'].count()
)
pd.options.display.float_format = '{:.2f}'.format
df_merged['ЗП (руб)'].describe()
# Out:
# Мода: 50000.0
#
# Значений менее 5к руб:
#  ЗП (руб)
# 1000.00    23
# 1.00       12
# 2000.00     7
# 1500.00     5
# 700.00      5
#            ..
# 3400.00     1
# 40.00       1
# 280.00      1
# 999.00      1
# 400.00      1
# Name: count, Length: 65, dtype: int64
#
# Желающих ЗП более 1млн руб: 22
# count      44744.00
# mean       78034.06
# std       161282.21
# min            1.00
# 25%        38000.00
# 50%        59038.00
# 75%        95000.00
# max     24304876.00
# Name: ЗП (руб), dtype: float64

# %%
summary_salary = {
    "min_salary": df_merged['ЗП (руб)'].min(),
    "max_salary": df_merged['ЗП (руб)'].max(),
    "median_salary": df_merged['ЗП (руб)'].median(),
    "mean_salary": df_merged['ЗП (руб)'].mean()
}
summary_salary
# Out:
# {'min_salary': 1.0,
#  'max_salary': 24304876.0,
#  'median_salary': 59037.99999999999,
#  'mean_salary': 78034.05533580689}

# %% [markdown]
# ваши выводы здесь
#
# min_salary: 1.0,
# max_salary: 24304876.0,
# median_salary: 59037.99999999999,
# mean_salary: 78034.05533580689

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь

# Фильтрация данных: зарплата меньше 1 млн рублей
filtered_data = df_merged[df_merged['ЗП (руб)'] < 10000000]

# Вычисление медианной зарплаты для каждого уровня образования
median_salary_by_education = filtered_data.groupby('Образование')['ЗП (руб)'].median().sort_values()

# Визуализация зависимости медианной зарплаты от уровня образования
plt.figure(figsize=(10, 6))
median_salary_by_education.plot(kind='bar', color='teal', alpha=0.8)

plt.title('Медианная заработная плата в зависимости от уровня образования')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная заработная плата (руб)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# Наибольшие уровни заработной платы наблюдаются для высших образований. Уровень ЗП важен при учете прогнозирования

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь
# Визуализация распределения заработной платы в зависимости от города
plt.figure(figsize=(12, 8))
sns.boxplot(
    df_merged,
    x='Город',
    y='ЗП (руб)',
    palette='coolwarm',
    showfliers=False
)

plt.title('Распределение заработной платы в зависимости от города')
plt.xlabel('Город')
plt.ylabel('Заработная плата (руб)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)


plt.tight_layout()
plt.show()
# Out:
# C:\Users\dimaa\AppData\Local\Temp\ipykernel_3196\3982121439.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# ваши выводы здесь
# Медианные уровни ЗП в городах примерно одинаковые, но Москва имеет больший уровень ЗП

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь
median_salary_by_mobility = filtered_data.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().unstack()

plt.figure(figsize=(12, 6))
median_salary_by_mobility.plot(kind='bar', stacked=False, figsize=(12, 6), color=['#1f77b4', '#ff7f0e'])

plt.title('Медианная заработная плата в зависимости от готовности к переезду и командировкам')
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная заработная плата (руб)')
plt.xticks(rotation=0)
plt.legend(title='Готовность к командировкам')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
median_salary_relocation_travel = filtered_data[
    (filtered_data['Готовность к переезду'] == True) &
    (filtered_data['Готовность к командировкам'] == True)
]['ЗП (руб)'].median()

print(f"Медианная заработная плата для соискателей, готовых и к переезду, и к командировкам: {round(median_salary_relocation_travel / 1000)} тыс. руб.")
# Out:
# Медианная заработная плата для соискателей, готовых и к переезду, и к командировкам: 67 тыс. руб.

# %% [markdown]
# ваши выводы здесь
# Медианная ЗП увеличивается, если соискатель готов на переезд/командировки

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь
pivot_table = pd.pivot_table(
    df_merged,
    values='ЗП (сумма)',  # Столбец с желаемой зарплатой
    index='Образование',  # Ряды - уровни образования
    columns='Возраст',    # Столбцы - возраст
    aggfunc='median'      # Функция агрегации - медиана
)

print(pivot_table)

plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, cmap='coolwarm', annot=True, fmt='.0f', cbar_kws={'label': 'Медианная ЗП'})
plt.title('Тепловая карта медианной желаемой зарплаты')
plt.xlabel('Возраст')
plt.ylabel('Образование')
plt.show()
# Out:
# Возраст                  14       15       16        17       18       19   \
# Образование
# Высшее              60000.00      NaN  1900.00 505000.00 25000.00 30000.00
# Неоконченное высшее      NaN      NaN      NaN  80000.00 25000.00 30000.00
# Среднее                  NaN 10000.00      NaN  44000.00 35000.00 55000.00
# Среднее специальное      NaN  2000.00 30000.00  25000.00 32500.00 30000.00
#
# Возраст                  20       21       22       23   ...       67   \
# Образование                                              ...
# Высшее              30000.00 40000.00 40000.00 50000.00  ...  70000.00
# Неоконченное высшее 35000.00 40000.00 40000.00 40000.00  ...       NaN
# Среднее             29000.00 50000.00 40000.00 40000.00  ...       NaN
# Среднее специальное 30000.00 30000.00 32000.00 35000.00  ... 120000.00
#
# Возраст                  68       69       70       71       72       73   \
# Образование
# ...

# %% [markdown]
# ваши выводы здесь
#
# Интенсивность заработной платы наибольшая для категории с Высшим образованием

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь
# Перевод опыта работы из месяцев в годы
df_merged['Опыт работы (годы)'] = df['Опыт работы (месяц)'] / 12

# Создание фигуры и диаграммы рассеяния
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_merged, x='Возраст', y='Опыт работы (годы)', alpha=0.6, color='blue', label='Данные')

# Добавление прямой y = x
x = [0, df['Возраст'].max()]
y = [0, df['Возраст'].max()]
plt.plot(x, y, color='red', linestyle='--', label='Прямая y = x')

# Настройка графика
plt.title('Диаграмма рассеяния: Опыт работы (годы) vs Возраст')
plt.xlabel('Возраст (лет)')
plt.ylabel('Опыт работы (годы)')
plt.legend()
plt.grid()

# Отображение графика
plt.show()

# %% [markdown]
# ваши выводы здесь
#
# Всего в наших данных 7 аномалий

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь
# Проверить, имеет ли уровень образования влияние на накопленный опыт работы. Это позволит оценить, является ли образование сильным фактором в накоплении опыта.
# Вычисление медианного опыта работы для каждого уровня образования
education_experience = filtered_data.groupby('Образование')['Опыт работы (месяц)'].median().sort_values()

# Построение графика
plt.figure(figsize=(10, 6))
education_experience.plot(kind='bar', color='skyblue', alpha=0.8)

plt.title('Зависимость опыта работы от уровня образования')
plt.xlabel('Уровень образования')
plt.ylabel('Медианный опыт работы (месяц)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Фильтрация данных: опыт работы меньше 600 месяцев (50 лет)
# Сравнить распределение опыта работы среди соискателей с разным уровнем образования. Это может помочь выявить различия в карьерных траекториях.
filtered_data = df_merged[df_merged['Опыт работы (месяц)'] < 600]

# Построение графика
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=filtered_data,
    x='Образование',
    y='Опыт работы (месяц)',
    palette='Set3',
    showfliers=False
)

plt.title('Распределение опыта работы в зависимости от уровня образования')
plt.xlabel('Уровень образования')
plt.ylabel('Опыт работы (месяц)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\dimaa\AppData\Local\Temp\ipykernel_3196\1188547849.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# ваши выводы здесь
#
# 1) Люди с более высоким уровнем образования (например, "Высшее" или "Неоконченное высшее") имеют медианно больший опыт работы
# 2) Уровень образования явно влияет на накопленный опыт работы.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь
duplicates_count = df_merged.duplicated().sum()

# Удаление полных дубликатов
df_merged = df_merged.drop_duplicates()

# Проверка количества дубликатов после удаления
duplicates_count_after = df_merged.duplicated().sum()
print(f"Количество полных дубликатов после удаления: {duplicates_count_after}")
# Out:
# Количество полных дубликатов после удаления: 0

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь
missing_values = df_merged.isnull().sum()

# Вывод столбцов с пропусками
missing_info = missing_values[missing_values > 0].sort_values(ascending=False)
print("Число пропусков в столбцах с пропусками:\n")
print(missing_info)

# Вычисление процента пропусков
missing_percentage = (missing_info / len(df_merged)) * 100
print("\nПроцент пропусков в столбцах с пропусками:\n")
print(missing_percentage)
# Out:
# Число пропусков в столбцах с пропусками:
#
# currency                           42341
# per                                42341
# date                               42341
# time                               42341
# vol                                42341
# Опыт работы (месяц)                  168
# Опыт работы (годы)                   168
# ЗП (валюта)                           29
# Последняя/нынешняя должность           2
# Последнее/нынешнее место работы        1
# dtype: int64
#
# Процент пропусков в столбцах с пропусками:
#
# currency                          94.97
# per                               94.97
# date                              94.97
# time                              94.97
# vol                               94.97
# Опыт работы (месяц)                0.38
# Опыт работы (годы)                 0.38
# ЗП (валюта)                        0.07
# Последняя/нынешняя должность       0.00
# Последнее/нынешнее место работы    0.00
# dtype: float64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код 
# Удаление строк с пропусками в столбцах "Последнее/нынешнее место работы" и "Последняя/нынешняя должность"
df_merged = df_merged.dropna(subset=["Последнее/нынешнее место работы", "Последняя/нынешняя должность"])

# Заполнение пропусков в столбце "Опыт работы (месяц)" медианным значением
median_experience = df_merged["Опыт работы (месяц)"].median()
df_merged["Опыт работы (месяц)"] = df_merged["Опыт работы (месяц)"].fillna(median_experience)

# Проверка на наличие пропусков после обработки
print("Оставшиеся пропуски после обработки:\n")
print(df_merged.isnull().sum())
# Out:
# Оставшиеся пропуски после обработки:
#
# ЗП                                     0
# Ищет работу на должность:              0
# Последнее/нынешнее место работы        0
# Последняя/нынешняя должность           0
# Обновление резюме                      0
# Авто                                   0
# Образование                            0
# Пол                                    0
# Возраст                                0
# Опыт работы (месяц)                    0
# Город                                  0
# Готовность к переезду                  0
# Готовность к командировкам             0
# полная занятость                       0
# частичная занятость                    0
# проектная работа                       0
# волонтерство                           0
# стажировка                             0
# полный день                            0
# сменный график                         0
# гибкий график                          0
# удаленная работа                       0
# ...

# %%
average_experience = round(df_merged["Опыт работы (месяц)"].mean())

average_experience
# Out:
# 115

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь
# Повторная попытка выполнения фильтрации для удаления выбросов
df_merged_cleaned = df_merged[(df_merged['ЗП (руб)'] >= 1000) & (df_merged['ЗП (руб)'] <= 1_000_000)]

# Проверка описательной статистики по столбцу "ЗП (руб)" после очистки данных
df_merged_cleaned['ЗП (руб)'].describe()
# Out:
# count     44473.00
# mean      75822.40
# std       60717.10
# min        1000.00
# 25%       38000.00
# 50%       59999.00
# 75%       95000.00
# max     1000000.00
# Name: ЗП (руб), dtype: float64

# %%
# Условие для выбросов
outliers_condition = (df_merged['ЗП (руб)'] < 1_000)

# Подсчет выбросов
outliers_count = df_merged[outliers_condition].shape[0]

print(f"Количество выбросов: {outliers_count}")
# Out:
# Количество выбросов: 86

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь
# Перевод опыта работы в годы и нахождение аномалий
invalid_experience_condition = (df_merged['Опыт работы (месяц)'] / 12 > df_merged['Возраст'])

# Подсчет таких резюме
invalid_experience_count = df_merged[invalid_experience_condition].shape[0]

print(f"Количество резюме с некорректным опытом работы: {invalid_experience_count}")

# Удаление таких строк из данных
df_merged = df_merged[~invalid_experience_condition]

print(f"Данные после удаления некорректных резюме: {df_merged.shape}")
# Out:
# Количество резюме с некорректным опытом работы: 7
# Данные после удаления некорректных резюме: (44574, 34)

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
from scipy.stats import zscore
# ваш код здесь
df_merged['log_Возраст'] = np.log(df_merged['Возраст'])

# Расчет статистик
log_mean = df_merged['log_Возраст'].mean()
log_std = df_merged['log_Возраст'].std()

# Границы метода трех сигм (с послаблением +1 сигма для правой стороны)
left_bound = log_mean - 3 * log_std
right_bound = log_mean + 4 * log_std

# Построение гистограммы
plt.figure(figsize=(10, 6))
histplot = sns.histplot(df_merged['log_Возраст'], bins=30, kde=True, color='blue', alpha=0.6)
histplot.axvline(log_mean, color='k', lw=2, label='Среднее')
histplot.axvline(left_bound, color='red', lw=2, linestyle='--', label='Левая граница (3 сигмы)')
histplot.axvline(right_bound, color='green', lw=2, linestyle='--', label='Правая граница (4 сигмы)')
plt.title('Распределение логарифма возраста с границами метода трех сигм')
plt.xlabel('Логарифм возраста')
plt.ylabel('Частота')
plt.legend()
plt.show()

# Поиск выбросов
z_scores = zscore(df_merged['log_Возраст'])
is_outlier = (df_merged['log_Возраст'] < left_bound) | (df_merged['log_Возраст'] > right_bound)

# Таблица выбросов
outliers = df_merged[is_outlier]

# Вывод количества выбросов и их значений
print(f"Количество выбросов: {outliers.shape[0]}")
print(outliers[['Возраст', 'log_Возраст']])

# Удаление выбросов из данных
df_merged = df_merged[~is_outlier]

print(f"Размер данных после удаления выбросов: {df_merged.shape}")
# Out:
# Количество выбросов: 3
#        Возраст  log_Возраст
# 31137       15         2.71
# 32950       15         2.71
# 33654      100         4.61
# Размер данных после удаления выбросов: (44571, 35)

# %% [markdown]
# ваш коммментарий здесь
#
# 1) На представленной гистограмме распределение логарифма возраста действительно асимметрично вправо, что указывает на присутствие людей с возрастом выше среднего. Хвост распределения уходит дальше в сторону больших значений.
# 2) С возрастами 15 и 100 лет
